# %%
# importing required libraries

import pandas as pd
pd.set_option('display.max_columns', None)
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('./MLZilla Data Set.xlsx')
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female            0.0     Yes         No     1.0           No
# 1  5575-GNVDE    Male            0.0      No         No    34.0          Yes
# 2  3668-QPYBK    Male            0.0      No         No     NaN          Yes
# 3  7795-CFOCW    Male            0.0      No         No    45.0           No
# 4  9237-HQITU  Female            0.0      No         No     2.0          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2               NaN             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# 1              Yes          No          No              No        One year
# 2               No          No          No              No             NaN
# 3              Yes         Yes          No              No        One year
# 4               No          No          No              No  Month-to-month
#
#   PaperlessBilling              PaymentMethod  MonthlyCharges TotalCharges  \
# 0              Yes           Electronic check           29.85        29.85
# 1               No               Mailed check           56.95       1889.5
# 2              Yes               Mailed check             NaN       108.15
# 3               No  Bank transfer (automatic)           42.30      1840.75
# 4              Yes           Electronic check           70.70       151.65
#
#   Churn  CustomerLifetimeValue  CustomerSatisfactionScore  NetPromoterScore  \
# 0    No            4370.861070                        2.0              84.0
# 1    No            9556.428758                        9.0               0.0
# 2   Yes            7587.945476                        3.0              31.0
# 3    No            6387.926358                        4.0              29.0
# 4   Yes            2404.167764                        1.0             -89.0
#
#    AverageCallDuration  NumberOfComplaints PreferredContactMethod  \
# 0            17.526822                 2.0                    SMS
# 1            10.601054                 3.0                  Phone
# 2            45.091316                 NaN                    SMS
# 3            14.931076                 4.0                  Email
# 4             8.830655                 2.0                    SMS
#
#   LastInteractionDate  PromotionalOffersUsed  BillingCycle  NumberOfDependents
# 0     00:44:18.200000                    1.0          26.0                 1.0
# 1     00:44:18.200000                    3.0           3.0                 1.0
# 2     00:44:18.200000                    1.0          19.0                 3.0
# 3     00:44:18.200000                    0.0          16.0                 3.0
# 4     00:44:18.200000                    0.0           1.0                 3.0

# %%
df.sample(8)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 3306  9430-NKQLY    Male            0.0     Yes        Yes    72.0
# 2653  6599-GZWCM  Female            0.0      No         No    13.0
# 3543  6823-SIDFQ    Male            0.0      No         No    28.0
# 6970  2245-ADZFJ  Female            0.0     Yes        Yes    31.0
# 953   8357-EQXFO  Female            0.0      No         No     7.0
# 395   4800-VHZKI  Female            0.0      No         No     1.0
# 410   8111-BKVDS  Female            0.0      No         No    10.0
# 309   2840-XANRC    Male            1.0     Yes         No     NaN
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  \
# 3306          NaN               Yes             NaN  No internet service
# 2653          Yes                No     Fiber optic                   No
# 3543          Yes                No              No  No internet service
# 6970          Yes               Yes  OutlierService                   No
# 953           Yes                No     Fiber optic                   No
# 395           Yes                No              No  No internet service
# 410            No  No phone service             DSL                  Yes
# 309           Yes                No     Fiber optic                   No
#
#              OnlineBackup     DeviceProtection          TechSupport  \
# 3306  No internet service  No internet service  No internet service
# 2653                  Yes                   No                   No
# 3543  No internet service  No internet service  No internet service
# 6970                  Yes                   No                  Yes
# 953                    No                  Yes                   No
# 395   No internet service  No internet service  No internet service
# 410                   Yes                  Yes                   No
# 309                    No                  Yes                   No
#
#               StreamingTV      StreamingMovies        Contract  \
# 3306  No internet service  No internet service        Two year
# 2653                   No                   No        One year
# 3543                  NaN  No internet service        One year
# 6970                  Yes                  Yes        Two year
# 953                   Yes                  Yes  Month-to-month
# 395   No internet service  No internet service  Month-to-month
# 410                    No                   No  Month-to-month
# 309                   Yes                  Yes  Month-to-month
#
#      PaperlessBilling              PaymentMethod  MonthlyCharges TotalCharges  \
# 3306              Yes    Credit card (automatic)           25.10       1790.8
# 2653              Yes               Mailed check           74.65       966.25
# 3543               No    Credit card (automatic)           18.25        534.7
# 6970               No  Bank transfer (automatic)           80.55       2471.6
# 953               Yes           Electronic check           95.35        660.9
# 395               Yes               Mailed check           19.90         19.9
# 410                No  Bank transfer (automatic)           40.70        449.3
# 309               Yes           Electronic check           93.15          NaN
#
#      Churn  CustomerLifetimeValue  CustomerSatisfactionScore  \
# 3306    No            5096.547926                   4.000000
# 2653    No            5009.874749                   4.000000
# 3543    No            3349.436736                        NaN
# 6970    No            8372.699735                  19.913224
# 953    Yes            2666.196360                   2.000000
# 395    Yes            9148.437788                   3.000000
# 410     No            1518.028840                   3.000000
# 309    Yes            2407.933384                   8.000000
#
#       NetPromoterScore  AverageCallDuration  NumberOfComplaints  \
# 3306             -76.0            20.167282                 0.0
# 2653             -88.0            20.132008                 2.0
# 3543             -66.0            55.235421                 3.0
# 6970              75.0            54.033535                 3.0
# 953               52.0            10.799675                 0.0
# 395              -12.0            34.885344                 1.0
# 410               24.0            36.327063                 4.0
# 309               -4.0            33.701857                 0.0
#
#      PreferredContactMethod LastInteractionDate  PromotionalOffersUsed  \
# 3306                  Phone     00:44:18.200000                    3.0
# 2653                    SMS     00:44:18.200000                    0.0
# 3543                  Email     00:44:18.200000                    3.0
# 6970                    SMS     00:44:18.200000                   13.0
# 953                   Email     00:44:18.200000                    1.0
# 395                   Phone     00:44:18.200000                    0.0
# 410                     SMS     00:44:18.200000                    3.0
# 309                   Phone     00:44:18.200000                    1.0
#
#       BillingCycle  NumberOfDependents
# 3306           8.0                 0.0
# 2653          24.0                 2.0
# 3543          16.0                 0.0
# 6970           2.0                 3.0
# 953           27.0                 0.0
# 395           24.0                 1.0
# 410           17.0                 1.0
# 309           20.0                 3.0

# %%
df.shape
# Out:
# (7205, 31)

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn',
#        'CustomerLifetimeValue', 'CustomerSatisfactionScore',
#        'NetPromoterScore', 'AverageCallDuration', 'NumberOfComplaints',
#        'PreferredContactMethod', 'LastInteractionDate',
#        'PromotionalOffersUsed', 'BillingCycle', 'NumberOfDependents'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7205 entries, 0 to 7204
# Data columns (total 31 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   customerID                 6886 non-null   object
#  1   gender                     6897 non-null   object
#  2   SeniorCitizen              6877 non-null   float64
#  3   Partner                    6906 non-null   object
#  4   Dependents                 6921 non-null   object
#  5   tenure                     6560 non-null   float64
#  6   PhoneService               6888 non-null   object
#  7   MultipleLines              6882 non-null   object
#  8   InternetService            6247 non-null   object
#  9   OnlineSecurity             6892 non-null   object
#  10  OnlineBackup               6894 non-null   object
#  11  DeviceProtection           6883 non-null   object
#  12  TechSupport                6900 non-null   object
#  13  StreamingTV                6904 non-null   object
#  14  StreamingMovies            6899 non-null   object
#  15  Contract                   6898 non-null   object
#  16  PaperlessBilling           6895 non-null   object
#  17  PaymentMethod              6907 non-null   object
#  18  MonthlyCharges             6549 non-null   float64
#  19  TotalCharges               6568 non-null   object
#  20  Churn                      6927 non-null   object
#  21  CustomerLifetimeValue      6895 non-null   float64
#  22  CustomerSatisfactionScore  5955 non-null   float64
#  23  NetPromoterScore           6911 non-null   float64
#  24  AverageCallDuration        6922 non-null   float64
#  25  NumberOfComplaints         6894 non-null   float64
#  26  PreferredContactMethod     6904 non-null   object
#  27  LastInteractionDate        6889 non-null   object
#  28  PromotionalOffersUsed      6241 non-null   float64
#  29  BillingCycle               6904 non-null   float64
#  30  NumberOfDependents         6895 non-null   float64
# dtypes: float64(11), object(20)
# memory usage: 1.7+ MB

# %%
missing_values = (df.isna().sum() / len(df)) * 100
print(missing_values)
# Out:
# customerID                    4.427481
# gender                        4.274809
# SeniorCitizen                 4.552394
# Partner                       4.149896
# Dependents                    3.941707
# tenure                        8.952117
# PhoneService                  4.399722
# MultipleLines                 4.482998
# InternetService              13.296322
# OnlineSecurity                4.344205
# OnlineBackup                  4.316447
# DeviceProtection              4.469119
# TechSupport                   4.233171
# StreamingTV                   4.177654
# StreamingMovies               4.247051
# Contract                      4.260930
# PaperlessBilling              4.302568
# PaymentMethod                 4.136017
# MonthlyCharges                9.104788
# TotalCharges                  8.841083
# Churn                         3.858432
# CustomerLifetimeValue         4.302568
# CustomerSatisfactionScore    17.349063
# NetPromoterScore              4.080500
# AverageCallDuration           3.927828
# NumberOfComplaints            4.316447
# PreferredContactMethod        4.177654
# LastInteractionDate           4.385843
# PromotionalOffersUsed        13.379598
# BillingCycle                  4.177654
# NumberOfDependents            4.302568
# dtype: float64

# %%
## 4.1 Imputing Columns with < 5% Missing Values
# Numerical Columns
numerical_cols = ['SeniorCitizen', 'MonthlyCharges', 'BillingCycle', 'NumberOfDependents']
for col in numerical_cols:
    if df[col].isna().sum() > 0:
        df[col].fillna(df[col].mean(), inplace=True)
# Out:
# /var/folders/7t/xg6m61nx0g57zw6nlz6cwrl80000gn/T/ipykernel_40038/3309890533.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].mean(), inplace=True)

# %%
categorical_cols = ['gender', 'Partner', 'Dependents', 'PhoneService', 'MultipleLines', 
                     'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport', 
                     'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod']
for col in categorical_cols:
    if df[col].isna().sum() > 0:
        df[col].fillna(df[col].mode()[0], inplace=True)
# Out:
# /var/folders/7t/xg6m61nx0g57zw6nlz6cwrl80000gn/T/ipykernel_40038/3575568459.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].mode()[0], inplace=True)

# %%
## 4.2 Handling Columns with 5% - 15% Missing Values
# Impute if important, drop if not critical
important_cols = ['InternetService']
less_important_cols = ['PromotionalOffersUsed']

# %%
df['InternetService'].fillna(df['InternetService'].mode()[0], inplace=True)
# Out:
# /var/folders/7t/xg6m61nx0g57zw6nlz6cwrl80000gn/T/ipykernel_40038/3024633505.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['InternetService'].fillna(df['InternetService'].mode()[0], inplace=True)

# %%
df.drop('PromotionalOffersUsed', axis=1, inplace=True)

# %%
df.drop(['CustomerSatisfactionScore'], axis=1, inplace=True)

# %%
df = df[df['Churn'].notna()]

# %%
df = df[df['customerID'].notna()]

# %%
df['tenure'].fillna(df['tenure'].median(), inplace=True)
# Out:
# /var/folders/7t/xg6m61nx0g57zw6nlz6cwrl80000gn/T/ipykernel_40038/2654990666.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['tenure'].fillna(df['tenure'].median(), inplace=True)

# %%
df['TotalCharges'] = pd.to_numeric(df['TotalCharges'], errors='coerce')
df['TotalCharges'].fillna(df['TotalCharges'].median(), inplace=True)
# Out:
# /var/folders/7t/xg6m61nx0g57zw6nlz6cwrl80000gn/T/ipykernel_40038/266577964.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['TotalCharges'].fillna(df['TotalCharges'].median(), inplace=True)

# %%
df['CustomerLifetimeValue'].fillna(df['CustomerLifetimeValue'].mean(), inplace=True)
# Out:
# /var/folders/7t/xg6m61nx0g57zw6nlz6cwrl80000gn/T/ipykernel_40038/1390774395.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['CustomerLifetimeValue'].fillna(df['CustomerLifetimeValue'].mean(), inplace=True)

# %%
df['NetPromoterScore'].fillna(df['NetPromoterScore'].median(), inplace=True)
# Out:
# /var/folders/7t/xg6m61nx0g57zw6nlz6cwrl80000gn/T/ipykernel_40038/2606063808.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['NetPromoterScore'].fillna(df['NetPromoterScore'].median(), inplace=True)

# %%
df['LastInteractionDate'].fillna(df['LastInteractionDate'].mode()[0], inplace=True)
# Out:
# /var/folders/7t/xg6m61nx0g57zw6nlz6cwrl80000gn/T/ipykernel_40038/2720145210.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['LastInteractionDate'].fillna(df['LastInteractionDate'].mode()[0], inplace=True)

# %%
print("\nFinal Missing Values Check:")
print((df.isna().sum() / len(df)) * 100)
# Out:
# Final Missing Values Check:
# customerID                0.000000
# gender                    0.000000
# SeniorCitizen             0.000000
# Partner                   0.000000
# Dependents                0.000000
# tenure                    0.000000
# PhoneService              0.000000
# MultipleLines             0.000000
# InternetService           0.000000
# OnlineSecurity            0.000000
# OnlineBackup              0.000000
# DeviceProtection          0.000000
# TechSupport               0.000000
# StreamingTV               0.000000
# StreamingMovies           0.000000
# Contract                  0.000000
# PaperlessBilling          0.000000
# PaymentMethod             0.000000
# MonthlyCharges            0.000000
# TotalCharges              0.000000
# Churn                     0.000000
# CustomerLifetimeValue     0.000000
# NetPromoterScore          0.000000
# AverageCallDuration       1.235294
# NumberOfComplaints        1.632353
# PreferredContactMethod    1.588235
# LastInteractionDate       0.000000
# BillingCycle              0.000000
# NumberOfDependents        0.000000
# dtype: float64

# %%
duplicate_rows = df[df.duplicated()]
print("Duplicate Rows:")
print(duplicate_rows)
# Out:
# Duplicate Rows:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 6873  1728-BQDMA  Female            0.0      No         No     2.0
# 6874  1803-BGNBD  Female            0.0      No         No    12.0
# 6875  4160-AMJTL  Female            1.0      No         No    28.0
# 6876  5192-EBGOV  Female            1.0      No         No     1.0
# 6878  8402-EIVQS    Male            0.0     Yes         No    67.0
# ...          ...     ...            ...     ...        ...     ...
# 7199  3308-DGHKL    Male            0.0      No         No    69.0
# 7201  6195-MELTI    Male            0.0      No         No    57.0
# 7202  8945-MUQUF    Male            0.0      No         No    51.0
# 7203  5921-NGYRH    Male            0.0     Yes         No    64.0
# 7204  9398-MMQTO    Male            0.0      No         No     3.0
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  \
# 6873          Yes            No             DSL                   No
# 6874          Yes            No             DSL                   No
# 6875          Yes            No              No                   No
# 6876          Yes           Yes     Fiber optic                   No
# 6878          Yes            No     Fiber optic                  Yes
# ...           ...           ...             ...                  ...
# 7199          Yes            No              No  No internet service
# 7201          Yes            No  OutlierService                   No
# 7202          Yes           Yes     Fiber optic                  Yes
# 7203          Yes            No     Fiber optic                  Yes
# 7204          Yes            No     Fiber optic                   No
#
#              OnlineBackup     DeviceProtection          TechSupport  \
# 6873                   No                   No                   No
# 6874                  Yes                   No                  Yes
# 6875  No internet service  No internet service  No internet service
# 6876                   No                   No                   No
# 6878                  Yes                   No                   No
# ...                   ...                  ...                  ...
# 7199  No internet service  No internet service  No internet service
# 7201                  Yes                   No                  Yes
# 7202                  Yes                   No                   No
# 7203                   No                   No                   No
# 7204                  Yes                   No                   No
#
#               StreamingTV      StreamingMovies        Contract  \
# 6873                   No                   No  Month-to-month
# 6874                   No                   No  Month-to-month
# 6875  No internet service  No internet service  Month-to-month
# 6876                  Yes                   No  Month-to-month
# 6878                  Yes                  Yes        One year
# ...                   ...                  ...             ...
# 7199  No internet service  No internet service        Two year
# 7201                   No                   No        One year
# 7202                  Yes                   No        One year
# 7203                   No                   No  Month-to-month
# 7204                   No                   No  Month-to-month
#
#      PaperlessBilling              PaymentMethod  MonthlyCharges  \
# 6873               No           Electronic check           44.45
# 6874              Yes           Electronic check           54.30
# 6875               No           Electronic check           19.65
# 6876              Yes           Electronic check           85.70
# 6878              Yes    Credit card (automatic)          100.90
# ...               ...                        ...             ...
# 7199              Yes  Bank transfer (automatic)           19.30
# 7201              Yes               Mailed check           54.65
# 7202              Yes           Electronic check           94.80
# 7203              Yes               Mailed check           73.55
# 7204               No    Credit card (automatic)           74.45
#
#       TotalCharges Churn  CustomerLifetimeValue  NetPromoterScore  \
# 6873      1372.675    No            4578.511407              56.0
# 6874       654.500    No            8213.834007             -51.0
# 6875       164.300   Yes            5488.250834              41.0
# 6876        85.700   Yes            3161.310569             -71.0
# 6878      6733.150    No            9385.783475             -23.0
# ...            ...   ...                    ...               ...
# 7199      1372.675    No            9902.127872               5.0
# 7201      3134.700    No            8949.462413             -61.0
# 7202      4837.600   Yes            2460.100652              53.0
# 7203      4764.000    No            5421.973887             -73.0
# 7204       221.100    No            2892.485601              92.0
#
#       AverageCallDuration  NumberOfComplaints PreferredContactMethod  \
# 6873            39.987964                 3.0                    SMS
# 6874            41.022146                 5.0                  Email
# 6875            49.490011                 4.0                  Phone
# 6876            48.338365                 4.0                  Email
# 6878            44.917296                 5.0                    SMS
# ...                   ...                 ...                    ...
# 7199            18.478101                 2.0                  Phone
# 7201            12.680028                 4.0                  Phone
# 7202            28.184115                 3.0                  Phone
# 7203            52.509896                 3.0                  Phone
# 7204            13.526890                 5.0                  Phone
#
#      LastInteractionDate  BillingCycle  NumberOfDependents
# 6873     00:44:18.200000          28.0                 0.0
# 6874     00:44:18.200000          17.0                 0.0
# 6875     00:44:18.200000          12.0                 0.0
# 6876     00:44:18.200000          16.0                 3.0
# 6878     00:44:18.200000          18.0                 2.0
# ...                  ...           ...                 ...
# 7199     00:44:18.200000           6.0                 2.0
# 7201     00:44:18.200000           9.0                 2.0
# 7202     00:44:18.200000           3.0                 2.0
# 7203     00:44:18.200000          24.0                 3.0
# 7204     00:44:18.200000           4.0                 0.0
#
# [321 rows x 29 columns]

# %%
df.drop_duplicates(inplace=True)

# %%
print("Duplicates After Removal:", df.duplicated().sum())
# Out:
# Duplicates After Removal: 0

# %%
# Statistical summary of numerical variables

df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges  TotalCharges  \
# count    6479.000000  6479.000000     6479.000000   6479.000000
# mean        0.161824    32.051551       64.595679   2215.632671
# std         0.364880    23.857774       29.123254   2206.240595
# min         0.000000     0.000000       18.250000     18.800000
# 25%         0.000000    10.000000       40.625000    433.000000
# 50%         0.000000    28.000000       67.850000   1372.675000
# 75%         0.000000    54.000000       89.000000   3554.675000
# max         1.000000    72.000000      118.750000   8684.800000
#
#        CustomerLifetimeValue  NetPromoterScore  AverageCallDuration  \
# count            6479.000000       6479.000000          6397.000000
# mean             5471.293926          0.080568            32.362205
# std              2587.565662         57.101581            15.917253
# min              1000.104713       -100.000000             5.000511
# 25%              3235.419411        -49.000000            18.478101
# 50%              5488.250834          0.000000            32.067549
# 75%              7708.767460         48.000000            46.212719
# max              9997.459060        100.000000            59.990219
#
#        NumberOfComplaints  BillingCycle  NumberOfDependents
# count         6376.000000   6479.000000         6479.000000
# mean             2.524467     15.460779            1.490141
# std              1.702325      8.640519            1.106646
# min              0.000000      1.000000            0.000000
# 25%              1.000000      8.000000            1.000000
# 50%              3.000000     15.456692            1.492096
# 75%              4.000000     23.000000            2.000000
# max              5.000000     30.000000            3.000000

# %%
# Descriptive Statistics
desc_stats = df.describe()

print("Descriptive Analysis:\n")

print("SeniorCitizen:")
print(f"- Approximately {desc_stats.loc['mean', 'SeniorCitizen']*100:.2f}% of customers are senior citizens.")
print(f"- This is a binary column (0 = Not Senior, 1 = Senior).")
print()

print("Tenure:")
print(f"- Average tenure is {desc_stats.loc['mean', 'tenure']:.2f} months.")
print(f"- Tenure ranges from {desc_stats.loc['min', 'tenure']} to {desc_stats.loc['max', 'tenure']} months.")
print(f"- Most customers have a tenure between {desc_stats.loc['25%', 'tenure']} and {desc_stats.loc['75%', 'tenure']} months.")
print(f"- Standard deviation is {desc_stats.loc['std', 'tenure']:.2f}, indicating moderate variability.")
print()

print("MonthlyCharges:")
print(f"- Average monthly charge is ${desc_stats.loc['mean', 'MonthlyCharges']:.2f}.")
print(f"- Charges range from ${desc_stats.loc['min', 'MonthlyCharges']} to ${desc_stats.loc['max', 'MonthlyCharges']}.")
print(f"- Majority of customers are charged between ${desc_stats.loc['25%', 'MonthlyCharges']} and ${desc_stats.loc['75%', 'MonthlyCharges']}.")
print(f"- Standard deviation is ${desc_stats.loc['std', 'MonthlyCharges']:.2f}, showing some variability.")
print()

print("TotalCharges:")
print(f"- Average total charges are ${desc_stats.loc['mean', 'TotalCharges']:.2f}.")
print(f"- Total charges range from ${desc_stats.loc['min', 'TotalCharges']} to ${desc_stats.loc['max', 'TotalCharges']}.")
print(f"- Most customers fall between ${desc_stats.loc['25%', 'TotalCharges']} and ${desc_stats.loc['75%', 'TotalCharges']}.")
print(f"- Standard deviation is ${desc_stats.loc['std', 'TotalCharges']:.2f}, indicating high variability.")
print()

print("CustomerLifetimeValue:")
print(f"- Average CLV is ${desc_stats.loc['mean', 'CustomerLifetimeValue']:.2f}.")
print(f"- CLV ranges from ${desc_stats.loc['min', 'CustomerLifetimeValue']} to ${desc_stats.loc['max', 'CustomerLifetimeValue']}.")
print(f"- Standard deviation of ${desc_stats.loc['std', 'CustomerLifetimeValue']:.2f} suggests significant variation.")
print()

print("NetPromoterScore:")
print(f"- The average NPS is {desc_stats.loc['mean', 'NetPromoterScore']:.2f}.")
print(f"- Scores range from {desc_stats.loc['min', 'NetPromoterScore']} to {desc_stats.loc['max', 'NetPromoterScore']}.")
print(f"- Most scores are between {desc_stats.loc['25%', 'NetPromoterScore']} and {desc_stats.loc['75%', 'NetPromoterScore']}.")
print()

print("AverageCallDuration:")
print(f"- Average call duration is {desc_stats.loc['mean', 'AverageCallDuration']:.2f} minutes.")
print(f"- Call durations range from {desc_stats.loc['min', 'AverageCallDuration']} to {desc_stats.loc['max', 'AverageCallDuration']} minutes.")
print(f"- Standard deviation is {desc_stats.loc['std', 'AverageCallDuration']:.2f}, indicating moderate variation.")
print()

print("NumberOfComplaints:")
print(f"- Average number of complaints is {desc_stats.loc['mean', 'NumberOfComplaints']:.2f}.")
print(f"- Complaints range from {desc_stats.loc['min', 'NumberOfComplaints']} to {desc_stats.loc['max', 'NumberOfComplaints']}.")
print()

print("BillingCycle:")
print(f"- Average billing cycle is {desc_stats.loc['mean', 'BillingCycle']:.2f} days.")
print(f"- Ranges from {desc_stats.loc['min', 'BillingCycle']} to {desc_stats.loc['max', 'BillingCycle']} days.")
print()

print("NumberOfDependents:")
print(f"- On average, customers have {desc_stats.loc['mean', 'NumberOfDependents']:.2f} dependents.")
print(f"- Number of dependents ranges from {desc_stats.loc['min', 'NumberOfDependents']} to {desc_stats.loc['max', 'NumberOfDependents']}.")
print()
# Out:
# Descriptive Analysis:
#
# SeniorCitizen:
# - Approximately 16.18% of customers are senior citizens.
# - This is a binary column (0 = Not Senior, 1 = Senior).
#
# Tenure:
# - Average tenure is 32.05 months.
# - Tenure ranges from 0.0 to 72.0 months.
# - Most customers have a tenure between 10.0 and 54.0 months.
# - Standard deviation is 23.86, indicating moderate variability.
#
# MonthlyCharges:
# - Average monthly charge is $64.60.
# - Charges range from $18.25 to $118.75.
# - Majority of customers are charged between $40.625 and $89.0.
# - Standard deviation is $29.12, showing some variability.
#
# TotalCharges:
# - Average total charges are $2215.63.
# - Total charges range from $18.8 to $8684.8.
# - Most customers fall between $433.0 and $3554.675.
# - Standard deviation is $2206.24, indicating high variability.
#
# CustomerLifetimeValue:
# - Average CLV is $5471.29.
# - CLV ranges from $1000.104713 to $9997.45906.
# - Standard deviation of $2587.57 suggests significant variation.
#
# NetPromoterScore:
# - The average NPS is 0.08.
# - Scores range from -100.0 to 100.0.
# - Most scores are between -49.0 and 48.0.
#
# AverageCallDuration:
# - Average call duration is 32.36 minutes.
# - Call durations range from 5.000511279 to 59.99021909 minutes.
# - Standard deviation is 15.92, indicating moderate variation.
#
# NumberOfComplaints:
# - Average number of complaints is 2.52.
# - Complaints range from 0.0 to 5.0.
#
# BillingCycle:
# - Average billing cycle is 15.46 days.
# - Ranges from 1.0 to 30.0 days.
#
# NumberOfDependents:
# - On average, customers have 1.49 dependents.
# - Number of dependents ranges from 0.0 to 3.0.

# %%
cat_summary = df.describe(include=['object'])

# %%
print("Statistical Summary of Categorical Variables:\n")
print(cat_summary)
print("\n")
# Out:
# Statistical Summary of Categorical Variables:
#
#         customerID gender Partner Dependents PhoneService MultipleLines  \
# count         6479   6479    6479       6479         6479          6479
# unique        6479      2       2          2            2             3
# top     7590-VHVEG   Male      No         No          Yes            No
# freq             1   3293    3385       4547         5870          3198
#
#        InternetService OnlineSecurity OnlineBackup DeviceProtection  \
# count             6479           6479         6479             6479
# unique               4              3            3                3
# top        Fiber optic             No           No               No
# freq              3093           3295         2886             2907
#
#        TechSupport StreamingTV StreamingMovies        Contract  \
# count         6479        6479            6479            6479
# unique           3           3               3               3
# top             No          No              No  Month-to-month
# freq          3246        2639            2609            3609
#
#        PaperlessBilling     PaymentMethod Churn PreferredContactMethod  \
# count              6479              6479  6479                   6376
# unique                2                 4     2                      3
# top                 Yes  Electronic check    No                    SMS
# freq               3867              2221  4771                   2208
#
#        LastInteractionDate
# count                 6479
# unique                   1
# top        00:44:18.200000
# freq                  6479

# %%
categorical_cols = df.select_dtypes(include=['object']).columns

# %%
for col in categorical_cols:
    print(f"🔍 Value Counts for '{col}':")
    print(df[col].value_counts())
    print("\n")
# Out:
# 🔍 Value Counts for 'customerID':
# customerID
# 7590-VHVEG    1
# 7486-KSRVI    1
# 2988-GBIVW    1
# 3647-GMGDH    1
# 8024-XNAFQ    1
#              ..
# 2972-YDYUW    1
# 4238-JSSWH    1
# 0869-PAPRP    1
# 2266-SJNAT    1
# 8361-LTMKD    1
# Name: count, Length: 6479, dtype: int64
#
#
# 🔍 Value Counts for 'gender':
# gender
# Male      3293
# Female    3186
# Name: count, dtype: int64
#
#
# 🔍 Value Counts for 'Partner':
# Partner
# No     3385
# Yes    3094
# Name: count, dtype: int64
#
#
# 🔍 Value Counts for 'Dependents':
# Dependents
# No     4547
# Yes    1932
# Name: count, dtype: int64
#
#
# 🔍 Value Counts for 'PhoneService':
# PhoneService
# Yes    5870
# No      609
# Name: count, dtype: int64
#
#
# 🔍 Value Counts for 'MultipleLines':
# MultipleLines
# No                  3198
# Yes                 2669
# No phone service     612
# Name: count, dtype: int64
#
#
# 🔍 Value Counts for 'InternetService':
# InternetService
# Fiber optic       3093
# DSL               1880
# No                1169
# OutlierService     337
# Name: count, dtype: int64
#
#
# 🔍 Value Counts for 'OnlineSecurity':
# OnlineSecurity
# No                     3295
# Yes                    1795
# No internet service    1389
# Name: count, dtype: int64
#
#
# 🔍 Value Counts for 'OnlineBackup':
# OnlineBackup
# No                     2886
# Yes                    2202
# No internet service    1391
# Name: count, dtype: int64
#
#
# 🔍 Value Counts for 'DeviceProtection':
# DeviceProtection
# No                     2907
# Yes                    2189
# No internet service    1383
# Name: count, dtype: int64
#
#
# 🔍 Value Counts for 'TechSupport':
# TechSupport
# No                     3246
# Yes                    1842
# No internet service    1391
# Name: count, dtype: int64
#
#
# 🔍 Value Counts for 'StreamingTV':
# StreamingTV
# No                     2639
# Yes                    2443
# No internet service    1397
# Name: count, dtype: int64
#
#
# 🔍 Value Counts for 'StreamingMovies':
# StreamingMovies
# No                     2609
# Yes                    2478
# No internet service    1392
# Name: count, dtype: int64
#
#
# 🔍 Value Counts for 'Contract':
# Contract
# Month-to-month    3609
# Two year          1536
# One year          1334
# Name: count, dtype: int64
#
#
# 🔍 Value Counts for 'PaperlessBilling':
# PaperlessBilling
# Yes    3867
# No     2612
# Name: count, dtype: int64
#
#
# 🔍 Value Counts for 'PaymentMethod':
# PaymentMethod
# Electronic check             2221
# Mailed check                 1460
# Bank transfer (automatic)    1415
# Credit card (automatic)      1383
# Name: count, dtype: int64
#
#
# 🔍 Value Counts for 'Churn':
# Churn
# No     4771
# Yes    1708
# Name: count, dtype: int64
#
#
# 🔍 Value Counts for 'PreferredContactMethod':
# PreferredContactMethod
# SMS      2208
# Phone    2100
# Email    2068
# Name: count, dtype: int64
#
#
# 🔍 Value Counts for 'LastInteractionDate':
# LastInteractionDate
# 00:44:18.200000    6479
# Name: count, dtype: int64

# %%
# Select numeric columns only
numeric_df = df.select_dtypes(include=['number'])

# %%
numeric_df = numeric_df.fillna(0)

# %%
correlation_matrix = numeric_df.corr()
print(correlation_matrix)
# Out:
#                        SeniorCitizen    tenure  MonthlyCharges  TotalCharges  \
# SeniorCitizen               1.000000  0.009750        0.208257      0.091621
# tenure                      0.009750  1.000000        0.236200      0.785493
# MonthlyCharges              0.208257  0.236200        1.000000      0.615899
# TotalCharges                0.091621  0.785493        0.615899      1.000000
# CustomerLifetimeValue      -0.007065  0.017441       -0.021099      0.000195
# NetPromoterScore            0.013056 -0.010538       -0.016676     -0.012531
# AverageCallDuration         0.007592  0.007782        0.025546      0.013267
# NumberOfComplaints         -0.003667 -0.006684        0.004683      0.003629
# BillingCycle               -0.007865 -0.003505       -0.027097     -0.010515
# NumberOfDependents          0.015177 -0.007907       -0.013815     -0.006719
#
#                        CustomerLifetimeValue  NetPromoterScore  \
# SeniorCitizen                      -0.007065          0.013056
# tenure                              0.017441         -0.010538
# MonthlyCharges                     -0.021099         -0.016676
# TotalCharges                        0.000195         -0.012531
# CustomerLifetimeValue               1.000000          0.017345
# NetPromoterScore                    0.017345          1.000000
# AverageCallDuration                -0.027526         -0.022235
# NumberOfComplaints                 -0.009279          0.012737
# BillingCycle                        0.000782          0.012916
# NumberOfDependents                 -0.013546          0.003779
#
#                        AverageCallDuration  NumberOfComplaints  BillingCycle  \
# SeniorCitizen                     0.007592           -0.003667     -0.007865
# tenure                            0.007782           -0.006684     -0.003505
# MonthlyCharges                    0.025546            0.004683     -0.027097
# TotalCharges                      0.013267            0.003629     -0.010515
# CustomerLifetimeValue            -0.027526           -0.009279      0.000782
# NetPromoterScore                 -0.022235            0.012737      0.012916
# AverageCallDuration               1.000000            0.008697      0.008744
# NumberOfComplaints                0.008697            1.000000     -0.018757
# BillingCycle                      0.008744           -0.018757      1.000000
# NumberOfDependents                0.010989            0.008149      0.002423
#
#                        NumberOfDependents
# SeniorCitizen                    0.015177
# tenure                          -0.007907
# MonthlyCharges                  -0.013815
# TotalCharges                    -0.006719
# CustomerLifetimeValue           -0.013546
# NetPromoterScore                 0.003779
# AverageCallDuration              0.010989
# NumberOfComplaints               0.008149
# BillingCycle                     0.002423
# NumberOfDependents               1.000000

# %%
corr_matrix = df.select_dtypes(include=['number']).fillna(0).corr()

plt.figure(figsize=(14, 10))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', square=True, fmt=".2f", annot_kws={"size": 10})  
plt.xticks(rotation=45, ha='right')  
plt.yticks(rotation=0)
plt.title('Correlation Matrix Heatmap', fontsize=16)
plt.tight_layout()  
plt.show()

# %% [markdown]
# Tenure and Total Charges
# Tenure and total charges have a strong positive correlation of 0.79.
# This indicates a significant linear relationship between how long a customer has been with the service and their total charges, suggesting that longer-tenured customers generate higher total charges, which is logical given the cumulative nature of charges over time.
#
#
# Monthly Charges and Total Charges
# Monthly charges and total charges show a strong positive correlation of 0.62.
# This strong relationship indicates that customers with higher monthly charges tend to have higher total charges, though the correlation is not perfect since total charges are also influenced by tenure.
#
#
# Tenure and Monthly Charges
# Tenure and monthly charges have a moderate positive correlation of 0.24.
# This suggests a weak to moderate relationship between how long a customer has been subscribed and their monthly charges, indicating that longer-term customers don't necessarily pay significantly higher monthly rates.
#
#
# Senior Citizen and Monthly Charges
# Senior citizen status and monthly charges show a weak positive correlation of 0.21.
# This indicates a slight tendency for senior citizens to have higher monthly charges, though the relationship is not strong.
#
#
# Customer Lifetime Value and Other Metrics
# Customer Lifetime Value shows virtually no significant correlation with any other metrics, with correlation values near 0 (ranging from -0.03 to 0.02).
# This suggests that CLV in this dataset is likely calculated or influenced by factors not captured in these metrics.
#
#
# Net Promoter Score Correlations
# Net Promoter Score shows very weak correlations with all other metrics (all correlations between -0.02 and 0.02).
# This indicates that customer satisfaction as measured by NPS is not strongly related to any of the other measured variables.
#
#
# Behavioral Metrics (Average Call Duration, Number of Complaints, Billing Cycle)
# These metrics show very weak correlations with all other variables (most correlations < ±0.03).
# This suggests that customer behavior in terms of call duration, complaints, and billing cycles operates independently of other customer characteristics and charges.
#
#
# Number of Dependents
# Number of dependents shows negligible correlations with all other metrics (all correlations ≤ ±0.02).
# This indicates that the number of dependents a customer has does not significantly influence or relate to any other measured aspects of their service usage or experience.

# %%
df.info
# Out:
# <bound method DataFrame.info of       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female            0.0     Yes         No     1.0
# 1     5575-GNVDE    Male            0.0      No         No    34.0
# 2     3668-QPYBK    Male            0.0      No         No    28.0
# 3     7795-CFOCW    Male            0.0      No         No    45.0
# 4     9237-HQITU  Female            0.0      No         No     2.0
# ...          ...     ...            ...     ...        ...     ...
# 6868  2569-WGERO  Female            0.0      No         No    72.0
# 6869  6840-RESVB    Male            0.0     Yes        Yes    24.0
# 6870  2234-XADUH  Female            0.0     Yes        Yes    72.0
# 6871  4801-JZAZL  Female            0.0     Yes        Yes    11.0
# 6872  8361-LTMKD    Male            1.0     Yes         No     4.0
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  \
# 0              No  No phone service             DSL                   No
# 1             Yes                No             DSL                  Yes
# 2             Yes                No             DSL                  Yes
# 3              No  No phone service             DSL                  Yes
# 4             Yes                No     Fiber optic                   No
# ...           ...               ...             ...                  ...
# 6868          Yes                No              No  No internet service
# 6869          Yes               Yes             DSL                  Yes
# 6870          Yes               Yes     Fiber optic                   No
# 6871           No  No phone service             DSL                  Yes
# 6872          Yes               Yes     Fiber optic                   No
#
#              OnlineBackup     DeviceProtection          TechSupport  \
# 0                     Yes                   No                   No
# 1                      No                  Yes                   No
# 2                     Yes                   No                   No
# 3                      No                  Yes                  Yes
# 4                      No                   No                   No
# ...                   ...                  ...                  ...
# 6868  No internet service  No internet service  No internet service
# 6869                   No                  Yes                  Yes
# 6870                  Yes                  Yes                   No
# 6871                   No                   No                   No
# 6872                   No                   No                   No
#
#               StreamingTV      StreamingMovies        Contract  \
# 0                      No                   No  Month-to-month
# 1                      No                   No        One year
# 2                      No                   No  Month-to-month
# 3                      No                   No        One year
# 4                      No                   No  Month-to-month
# ...                   ...                  ...             ...
# 6868  No internet service  No internet service        Two year
# 6869                  Yes                  Yes        One year
# 6870                  Yes                  Yes        One year
# 6871                   No                   No  Month-to-month
# 6872                   No                   No  Month-to-month
#
#      PaperlessBilling              PaymentMethod  MonthlyCharges  \
# 0                 Yes           Electronic check       29.850000
# 1                  No               Mailed check       56.950000
# 2                 Yes               Mailed check       64.433883
# 3                  No  Bank transfer (automatic)       42.300000
# 4                 Yes           Electronic check       70.700000
# ...               ...                        ...             ...
# 6868              Yes  Bank transfer (automatic)       21.150000
# 6869              Yes               Mailed check       84.800000
# 6870              Yes    Credit card (automatic)      103.200000
# 6871              Yes           Electronic check       29.600000
# 6872              Yes               Mailed check       74.400000
#
#       TotalCharges Churn  CustomerLifetimeValue  NetPromoterScore  \
# 0            29.85    No            4370.861070              84.0
# 1          1889.50    No            9556.428758               0.0
# 2           108.15   Yes            7587.945476              31.0
# 3          1840.75    No            6387.926358              29.0
# 4           151.65   Yes            2404.167764             -89.0
# ...            ...   ...                    ...               ...
# 6868       1419.40    No            5037.693325              46.0
# 6869       1990.50    No            5839.229157              29.0
# 6870       7362.90    No            6972.622487             -61.0
# 6871        346.45    No            8055.746655              66.0
# 6872        306.60   Yes            4553.265546             -10.0
#
#       AverageCallDuration  NumberOfComplaints PreferredContactMethod  \
# 0               17.526822                 2.0                    SMS
# 1               10.601054                 3.0                  Phone
# 2               45.091316                 NaN                    SMS
# 3               14.931076                 4.0                  Email
# 4                8.830655                 2.0                    SMS
# ...                   ...                 ...                    ...
# 6868            45.351335                 2.0                    SMS
# 6869            49.425165                 1.0                  Email
# 6870            24.468577                 0.0                  Email
# 6871            13.796117                 1.0                  Phone
# 6872            40.658946                 1.0                    SMS
#
#      LastInteractionDate  BillingCycle  NumberOfDependents
# 0        00:44:18.200000          26.0                 1.0
# 1        00:44:18.200000           3.0                 1.0
# 2        00:44:18.200000          19.0                 3.0
# 3        00:44:18.200000          16.0                 3.0
# 4        00:44:18.200000           1.0                 3.0
# ...                  ...           ...                 ...
# 6868     00:44:18.200000           9.0                 0.0
# 6869     00:44:18.200000          23.0                 0.0
# 6870     00:44:18.200000           5.0                 2.0
# 6871     00:44:18.200000           9.0                 1.0
# 6872     00:44:18.200000          19.0                 2.0
#
# [6479 rows x 29 columns]>

# %%
# Drop unnecessary columns
columns_to_drop = ['customerID', 'NetPromoterScore', 'CustomerLifetimeValue', 
                   'NumberOfDependents', 'LastInteractionDate', 'BillingCycle']  

df = df.drop(columns=columns_to_drop, errors='ignore')  
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6479 entries, 0 to 6872
# Data columns (total 23 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   gender                  6479 non-null   object
#  1   SeniorCitizen           6479 non-null   float64
#  2   Partner                 6479 non-null   object
#  3   Dependents              6479 non-null   object
#  4   tenure                  6479 non-null   float64
#  5   PhoneService            6479 non-null   object
#  6   MultipleLines           6479 non-null   object
#  7   InternetService         6479 non-null   object
#  8   OnlineSecurity          6479 non-null   object
#  9   OnlineBackup            6479 non-null   object
#  10  DeviceProtection        6479 non-null   object
#  11  TechSupport             6479 non-null   object
#  12  StreamingTV             6479 non-null   object
#  13  StreamingMovies         6479 non-null   object
#  14  Contract                6479 non-null   object
#  15  PaperlessBilling        6479 non-null   object
#  16  PaymentMethod           6479 non-null   object
#  17  MonthlyCharges          6479 non-null   float64
#  18  TotalCharges            6479 non-null   float64
#  19  Churn                   6479 non-null   object
#  20  AverageCallDuration     6397 non-null   float64
#  21  NumberOfComplaints      6376 non-null   float64
#  22  PreferredContactMethod  6376 non-null   object
# dtypes: float64(6), object(17)
# memory usage: 1.2+ MB

# %%
for column in df.columns:
    unique_values = df[column].unique()
    print(f"Unique values in '{column}': {unique_values}")
    print()

missing_values = df.isnull().sum()
data_types = df.dtypes
# Out:
# Unique values in 'gender': ['Female' 'Male']
#
# Unique values in 'SeniorCitizen': [0.         0.16082594 1.        ]
#
# Unique values in 'Partner': ['Yes' 'No']
#
# Unique values in 'Dependents': ['No' 'Yes']
#
# Unique values in 'tenure': [ 1. 34. 28. 45.  2.  8. 22. 10. 62. 13. 16. 58. 49. 25. 52. 71. 21. 12.
#  30. 47. 17. 27. 46. 11. 70. 63. 69. 15. 18. 66. 72. 60.  9.  3. 50. 64.
#  56.  7. 42. 35. 48. 29. 65. 38. 68.  5. 32. 43. 55. 37. 36. 41.  6.  4.
#  33. 67. 61. 14. 20. 53. 40. 59. 24. 19. 23. 31. 54. 57. 51. 44. 26.  0.
#  39.]
#
# Unique values in 'PhoneService': ['No' 'Yes']
#
# Unique values in 'MultipleLines': ['No phone service' 'No' 'Yes']
#
# Unique values in 'InternetService': ['DSL' 'Fiber optic' 'OutlierService' 'No']
#
# Unique values in 'OnlineSecurity': ['No' 'Yes' 'No internet service']
#
# Unique values in 'OnlineBackup': ['Yes' 'No' 'No internet service']
#
# Unique values in 'DeviceProtection': ['No' 'Yes' 'No internet service']
#
# Unique values in 'TechSupport': ['No' 'Yes' 'No internet service']
#
# Unique values in 'StreamingTV': ['No' 'Yes' 'No internet service']
#
# Unique values in 'StreamingMovies': ['No' 'Yes' 'No internet service']
#
# Unique values in 'Contract': ['Month-to-month' 'One year' 'Two year']
#
# Unique values in 'PaperlessBilling': ['Yes' 'No']
#
# Unique values in 'PaymentMethod': ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
#
# Unique values in 'MonthlyCharges': [ 29.85        56.95        64.43388304 ... 103.5         44.2
#   78.7       ]
#
# Unique values in 'TotalCharges': [  29.85 1889.5   108.15 ... 7362.9   346.45  306.6 ]
#
# Unique values in 'Churn': ['No' 'Yes']
#
# Unique values in 'AverageCallDuration': [17.52682217 10.60105379 45.09131564 ... 24.46857671 13.79611698
#  40.65894618]
#
# Unique values in 'NumberOfComplaints': [ 2.  3. nan  4.  1.  5.  0.]
#
# Unique values in 'PreferredContactMethod': ['SMS' 'Phone' 'Email' nan]

# %%
print('-'*50)
print("Missing values:")
print(missing_values)
print()
# Out:
# --------------------------------------------------
# Missing values:
# gender                      0
# SeniorCitizen               0
# Partner                     0
# Dependents                  0
# tenure                      0
# PhoneService                0
# MultipleLines               0
# InternetService             0
# OnlineSecurity              0
# OnlineBackup                0
# DeviceProtection            0
# TechSupport                 0
# StreamingTV                 0
# StreamingMovies             0
# Contract                    0
# PaperlessBilling            0
# PaymentMethod               0
# MonthlyCharges              0
# TotalCharges                0
# Churn                       0
# AverageCallDuration        82
# NumberOfComplaints        103
# PreferredContactMethod    103
# dtype: int64

# %%
df['AverageCallDuration'].fillna(df['AverageCallDuration'].median(), inplace=True)
df['NumberOfComplaints'].fillna(df['NumberOfComplaints'].median(), inplace=True)
# Out:
# /var/folders/7t/xg6m61nx0g57zw6nlz6cwrl80000gn/T/ipykernel_40038/3801579977.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['AverageCallDuration'].fillna(df['AverageCallDuration'].median(), inplace=True)
# /var/folders/7t/xg6m61nx0g57zw6nlz6cwrl80000gn/T/ipykernel_40038/3801579977.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['NumberOfComplaints'].fillna(df['NumberOfComplaints'].median(), inplace=True)

# %%
df['PreferredContactMethod'].fillna(df['PreferredContactMethod'].mode()[0], inplace=True)
# Out:
# /var/folders/7t/xg6m61nx0g57zw6nlz6cwrl80000gn/T/ipykernel_40038/345689678.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['PreferredContactMethod'].fillna(df['PreferredContactMethod'].mode()[0], inplace=True)

# %%
print("Missing values after cleaning:\n", df.isnull().sum())
# Out:
# Missing values after cleaning:
#  gender                    0
# SeniorCitizen             0
# Partner                   0
# Dependents                0
# tenure                    0
# PhoneService              0
# MultipleLines             0
# InternetService           0
# OnlineSecurity            0
# OnlineBackup              0
# DeviceProtection          0
# TechSupport               0
# StreamingTV               0
# StreamingMovies           0
# Contract                  0
# PaperlessBilling          0
# PaymentMethod             0
# MonthlyCharges            0
# TotalCharges              0
# Churn                     0
# AverageCallDuration       0
# NumberOfComplaints        0
# PreferredContactMethod    0
# dtype: int64

# %%
x = df.duplicated().sum()
print('-'*50)
print("Duplicate values:", x)
print()
# Out:
# --------------------------------------------------
# Duplicate values: 0

# %%
y = df.shape
print('-'*50)
print("Shape of Dataset:", y)
print()
# Out:
# --------------------------------------------------
# Shape of Dataset: (6479, 23)

# %%
z = df.columns
print('-'*50)
print("Columns of Datset:", z)
print()
# Out:
# --------------------------------------------------
# Columns of Datset: Index(['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure',
#        'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity',
#        'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV',
#        'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod',
#        'MonthlyCharges', 'TotalCharges', 'Churn', 'AverageCallDuration',
#        'NumberOfComplaints', 'PreferredContactMethod'],
#       dtype='object')

# %%
print('-'*50)
print("\nData types:")
print(data_types)
print()
# Out:
# --------------------------------------------------
#
# Data types:
# gender                     object
# SeniorCitizen             float64
# Partner                    object
# Dependents                 object
# tenure                    float64
# PhoneService               object
# MultipleLines              object
# InternetService            object
# OnlineSecurity             object
# OnlineBackup               object
# DeviceProtection           object
# TechSupport                object
# StreamingTV                object
# StreamingMovies            object
# Contract                   object
# PaperlessBilling           object
# PaymentMethod              object
# MonthlyCharges            float64
# TotalCharges              float64
# Churn                      object
# AverageCallDuration       float64
# NumberOfComplaints        float64
# PreferredContactMethod     object
# dtype: object

# %%
num_columns = len(df.columns)
fig, ax = plt.subplots(figsize=(10, 6))
if num_columns > 16:
    fig.set_size_inches(10, num_columns * 0.6)
else:
    fig.set_size_inches(num_columns, 6)

# Create a boxplot for each column
df.boxplot(ax=ax)

# Set the title and labels
plt.title("Boxplot of Columns")
plt.xlabel("Columns")
plt.ylabel("Values")

# Rotate the x-axis labels for better readability (optional)
plt.xticks(rotation=90)

# Show the plot
plt.show()

# %%
# Define a function to detect and remove outliers using IQR
def remove_outliers(df, column):
    Q1 = df[column].quantile(0.25)  # 25th percentile
    Q3 = df[column].quantile(0.75)  # 75th percentile
    IQR = Q3 - Q1  

    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    # Filter out outliers
    df_cleaned = df[(df[column] >= lower_bound) & (df[column] <= upper_bound)]
    
    return df_cleaned

df = remove_outliers(df, 'TotalCharges')

print(f"Shape after removing outliers: {df.shape}")
# Out:
# Shape after removing outliers: (6443, 23)

# %%
num_columns = len(df.columns)
fig, ax = plt.subplots(figsize=(10, 6))
if num_columns > 16:
    fig.set_size_inches(10, num_columns * 0.6)
else:
    fig.set_size_inches(num_columns, 6)

# Create a boxplot for each column
df.boxplot(ax=ax)

# Set the title and labels
plt.title("Boxplot of Columns")
plt.xlabel("Columns")
plt.ylabel("Values")

plt.xticks(rotation=90)

plt.show()

# %%
df_cleaned = df.copy()

# %%
categorical_columns = df.select_dtypes(include=['object']).columns
categorical_columns
# Out:
# Index(['gender', 'Partner', 'Dependents', 'PhoneService', 'MultipleLines',
#        'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
#        'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract',
#        'PaperlessBilling', 'PaymentMethod', 'PreferredContactMethod'],
#       dtype='object')

# %%
# Encode categorical columns
categorical_columns = ['gender', 'Partner', 'Dependents', 'PhoneService', 'MultipleLines',
                       'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
                       'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract',
                       'PaperlessBilling', 'PaymentMethod', 'PreferredContactMethod']

df = pd.get_dummies(df, columns=categorical_columns, drop_first=True)

print(df.head())
# Out:
#    SeniorCitizen  tenure  MonthlyCharges  TotalCharges  Churn  \
# 0            0.0     1.0       29.850000         29.85      0
# 1            0.0    34.0       56.950000       1889.50      0
# 2            0.0    28.0       64.433883        108.15      1
# 3            0.0    45.0       42.300000       1840.75      0
# 4            0.0     2.0       70.700000        151.65      1
#
#    AverageCallDuration  NumberOfComplaints  gender_Male  Partner_Yes  \
# 0            17.526822                 2.0        False         True
# 1            10.601054                 3.0         True        False
# 2            45.091316                 3.0         True        False
# 3            14.931076                 4.0         True        False
# 4             8.830655                 2.0        False        False
#
#    Dependents_Yes  PhoneService_Yes  MultipleLines_No phone service  \
# 0           False             False                            True
# 1           False              True                           False
# 2           False              True                           False
# 3           False             False                            True
# 4           False              True                           False
#
#    MultipleLines_Yes  InternetService_Fiber optic  InternetService_No  \
# 0              False                        False               False
# 1              False                        False               False
# 2              False                        False               False
# 3              False                        False               False
# 4              False                         True               False
#
#    InternetService_OutlierService  OnlineSecurity_No internet service  \
# 0                           False                               False
# 1                           False                               False
# 2                           False                               False
# 3                           False                               False
# 4                           False                               False
#
#    OnlineSecurity_Yes  OnlineBackup_No internet service  OnlineBackup_Yes  \
# 0               False                             False              True
# 1                True                             False             False
# 2                True                             False              True
# 3                True                             False             False
# 4               False                             False             False
#
#    DeviceProtection_No internet service  DeviceProtection_Yes  \
# 0                                 False                 False
# 1                                 False                  True
# 2                                 False                 False
# 3                                 False                  True
# 4                                 False                 False
#
#    TechSupport_No internet service  TechSupport_Yes  \
# 0                            False            False
# 1                            False            False
# 2                            False            False
# 3                            False             True
# 4                            False            False
#
#    StreamingTV_No internet service  StreamingTV_Yes  \
# 0                            False            False
# 1                            False            False
# 2                            False            False
# 3                            False            False
# 4                            False            False
#
#    StreamingMovies_No internet service  StreamingMovies_Yes  \
# 0                                False                False
# 1                                False                False
# 2                                False                False
# 3                                False                False
# 4                                False                False
#
#    Contract_One year  Contract_Two year  PaperlessBilling_Yes  \
# 0              False              False                  True
# 1               True              False                 False
# 2              False              False                  True
# 3               True              False                 False
# 4              False              False                  True
#
#    PaymentMethod_Credit card (automatic)  PaymentMethod_Electronic check  \
# 0                                  False                            True
# 1                                  False                           False
# 2                                  False                           False
# 3                                  False                           False
# 4                                  False                            True
#
#    PaymentMethod_Mailed check  PreferredContactMethod_Phone  \
# 0                       False                         False
# 1                        True                          True
# 2                        True                         False
# 3                       False                         False
# 4                       False                         False
#
#    PreferredContactMethod_SMS
# 0                        True
# 1                       False
# 2                        True
# 3                       False
# 4                        True

# %%
df.info
# Out:
# <bound method DataFrame.info of       SeniorCitizen  tenure  MonthlyCharges  TotalCharges  Churn  \
# 0               0.0     1.0       29.850000         29.85      0
# 1               0.0    34.0       56.950000       1889.50      0
# 2               0.0    28.0       64.433883        108.15      1
# 3               0.0    45.0       42.300000       1840.75      0
# 4               0.0     2.0       70.700000        151.65      1
# ...             ...     ...             ...           ...    ...
# 6868            0.0    72.0       21.150000       1419.40      0
# 6869            0.0    24.0       84.800000       1990.50      0
# 6870            0.0    72.0      103.200000       7362.90      0
# 6871            0.0    11.0       29.600000        346.45      0
# 6872            1.0     4.0       74.400000        306.60      1
#
#       AverageCallDuration  NumberOfComplaints  gender_Male  Partner_Yes  \
# 0               17.526822                 2.0        False         True
# 1               10.601054                 3.0         True        False
# 2               45.091316                 3.0         True        False
# 3               14.931076                 4.0         True        False
# 4                8.830655                 2.0        False        False
# ...                   ...                 ...          ...          ...
# 6868            45.351335                 2.0        False        False
# 6869            49.425165                 1.0         True         True
# 6870            24.468577                 0.0        False         True
# 6871            13.796117                 1.0        False         True
# 6872            40.658946                 1.0         True         True
#
#       Dependents_Yes  PhoneService_Yes  MultipleLines_No phone service  \
# 0              False             False                            True
# 1              False              True                           False
# 2              False              True                           False
# 3              False             False                            True
# 4              False              True                           False
# ...              ...               ...                             ...
# 6868           False              True                           False
# 6869            True              True                           False
# 6870            True              True                           False
# 6871            True             False                            True
# 6872           False              True                           False
#
#       MultipleLines_Yes  InternetService_Fiber optic  InternetService_No  \
# 0                 False                        False               False
# 1                 False                        False               False
# 2                 False                        False               False
# 3                 False                        False               False
# 4                 False                         True               False
# ...                 ...                          ...                 ...
# 6868              False                        False                True
# 6869               True                        False               False
# 6870               True                         True               False
# 6871              False                        False               False
# 6872               True                         True               False
#
#       InternetService_OutlierService  OnlineSecurity_No internet service  \
# 0                              False                               False
# 1                              False                               False
# 2                              False                               False
# 3                              False                               False
# 4                              False                               False
# ...                              ...                                 ...
# 6868                           False                                True
# 6869                           False                               False
# 6870                           False                               False
# 6871                           False                               False
# 6872                           False                               False
#
#       OnlineSecurity_Yes  OnlineBackup_No internet service  OnlineBackup_Yes  \
# 0                  False                             False              True
# 1                   True                             False             False
# 2                   True                             False              True
# 3                   True                             False             False
# 4                  False                             False             False
# ...                  ...                               ...               ...
# 6868               False                              True             False
# 6869                True                             False             False
# 6870               False                             False              True
# 6871                True                             False             False
# 6872               False                             False             False
#
#       DeviceProtection_No internet service  DeviceProtection_Yes  \
# 0                                    False                 False
# 1                                    False                  True
# 2                                    False                 False
# 3                                    False                  True
# 4                                    False                 False
# ...                                    ...                   ...
# 6868                                  True                 False
# 6869                                 False                  True
# 6870                                 False                  True
# 6871                                 False                 False
# 6872                                 False                 False
#
#       TechSupport_No internet service  TechSupport_Yes  \
# 0                               False            False
# 1                               False            False
# 2                               False            False
# 3                               False             True
# 4                               False            False
# ...                               ...              ...
# 6868                             True            False
# 6869                            False             True
# 6870                            False            False
# 6871                            False            False
# 6872                            False            False
#
#       StreamingTV_No internet service  StreamingTV_Yes  \
# 0                               False            False
# 1                               False            False
# 2                               False            False
# 3                               False            False
# 4                               False            False
# ...                               ...              ...
# 6868                             True            False
# 6869                            False             True
# 6870                            False             True
# 6871                            False            False
# 6872                            False            False
#
#       StreamingMovies_No internet service  StreamingMovies_Yes  \
# 0                                   False                False
# 1                                   False                False
# 2                                   False                False
# 3                                   False                False
# 4                                   False                False
# ...                                   ...                  ...
# 6868                                 True                False
# 6869                                False                 True
# 6870                                False                 True
# 6871                                False                False
# 6872                                False                False
#
#       Contract_One year  Contract_Two year  PaperlessBilling_Yes  \
# 0                 False              False                  True
# 1                  True              False                 False
# 2                 False              False                  True
# 3                  True              False                 False
# 4                 False              False                  True
# ...                 ...                ...                   ...
# 6868              False               True                  True
# 6869               True              False                  True
# 6870               True              False                  True
# 6871              False              False                  True
# 6872              False              False                  True
#
#       PaymentMethod_Credit card (automatic)  PaymentMethod_Electronic check  \
# 0                                     False                            True
# 1                                     False                           False
# 2                                     False                           False
# 3                                     False                           False
# 4                                     False                            True
# ...                                     ...                             ...
# 6868                                  False                           False
# 6869                                  False                           False
# 6870                                   True                           False
# 6871                                  False                            True
# 6872                                  False                           False
#
#       PaymentMethod_Mailed check  PreferredContactMethod_Phone  \
# 0                          False                         False
# 1                           True                          True
# 2                           True                         False
# 3                          False                         False
# 4                          False                         False
# ...                          ...                           ...
# 6868                       False                         False
# 6869                        True                         False
# 6870                       False                         False
# 6871                       False                          True
# 6872                        True                         False
#
#       PreferredContactMethod_SMS
# 0                           True
# 1                          False
# 2                           True
# 3                          False
# 4                           True
# ...                          ...
# 6868                        True
# 6869                       False
# 6870                       False
# 6871                       False
# 6872                        True
#
# [6443 rows x 36 columns]>

# %%
df.shape
# Out:
# (6443, 36)

# %%
import math

def sturges_rule(num_data_points):
    k = 1 + math.log2(num_data_points)
    return int(k)

# Use the number of rows in your dataset
num_data_points = df.shape[0]  # 6443 rows
bins = sturges_rule(num_data_points)

print("Number of bins according to Sturges' Rule:", bins)
# Out:
# Number of bins according to Sturges' Rule: 13

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Identify continuous variables (excluding binary ones)
continuous_vars = df.select_dtypes(include=['float64', 'int64']).columns

# Exclude binary variables (only two unique values)
binary_vars = [var for var in continuous_vars if df[var].nunique() == 2]
continuous_vars = [var for var in continuous_vars if var not in binary_vars]

# Set number of bins according to Sturges' Rule
num_bins = 13  # As per your previous calculation

# Plot the distribution of each continuous variable
for var in continuous_vars:
    plt.figure(figsize=(6, 4))
    sns.histplot(data=df, x=var, bins=num_bins, kde=True)
    plt.xlabel(var)
    plt.ylabel('Frequency')
    plt.title(f'Distribution of {var}')
    plt.show()

# %%
df[continuous_vars].skew()
# Out:
# SeniorCitizen          1.857780
# tenure                 0.295068
# MonthlyCharges        -0.229464
# TotalCharges           1.040150
# AverageCallDuration    0.030607
# NumberOfComplaints    -0.025137
# dtype: float64

# %%
# Compute correlation only for numeric columns
numeric_df = df.select_dtypes(include=['float64', 'int64'])  # Exclude categorical variables
corr_matrix = numeric_df.corr()

# Plot heatmap
plt.figure(figsize=(14, 8))  # Set figure size
sns.heatmap(corr_matrix, annot=len(corr_matrix.columns) <= 15, cmap='coolwarm', square=True, fmt=".2f")  # Avoid clutter
plt.title('Correlation Matrix Heatmap')
plt.show()

# %%
x = df.drop("Churn",axis=1)
y = df['Churn']
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# %%
X_train.shape, y_train.shape
# Out:
# ((4510, 35), (4510,))

# %%
X_test.shape, y_test.shape
# Out:
# ((1933, 35), (1933,))

# %%
df.head()
# Out:
#    SeniorCitizen  tenure  MonthlyCharges  TotalCharges  Churn  \
# 0            0.0     1.0       29.850000         29.85      0
# 1            0.0    34.0       56.950000       1889.50      0
# 2            0.0    28.0       64.433883        108.15      1
# 3            0.0    45.0       42.300000       1840.75      0
# 4            0.0     2.0       70.700000        151.65      1
#
#    AverageCallDuration  NumberOfComplaints  gender_Male  Partner_Yes  \
# 0            17.526822                 2.0        False         True
# 1            10.601054                 3.0         True        False
# 2            45.091316                 3.0         True        False
# 3            14.931076                 4.0         True        False
# 4             8.830655                 2.0        False        False
#
#    Dependents_Yes  PhoneService_Yes  MultipleLines_No phone service  \
# 0           False             False                            True
# 1           False              True                           False
# 2           False              True                           False
# 3           False             False                            True
# 4           False              True                           False
#
#    MultipleLines_Yes  InternetService_Fiber optic  InternetService_No  \
# 0              False                        False               False
# 1              False                        False               False
# 2              False                        False               False
# 3              False                        False               False
# 4              False                         True               False
#
#    InternetService_OutlierService  OnlineSecurity_No internet service  \
# 0                           False                               False
# 1                           False                               False
# 2                           False                               False
# 3                           False                               False
# 4                           False                               False
#
#    OnlineSecurity_Yes  OnlineBackup_No internet service  OnlineBackup_Yes  \
# 0               False                             False              True
# 1                True                             False             False
# 2                True                             False              True
# 3                True                             False             False
# 4               False                             False             False
#
#    DeviceProtection_No internet service  DeviceProtection_Yes  \
# 0                                 False                 False
# 1                                 False                  True
# 2                                 False                 False
# 3                                 False                  True
# 4                                 False                 False
#
#    TechSupport_No internet service  TechSupport_Yes  \
# 0                            False            False
# 1                            False            False
# 2                            False            False
# 3                            False             True
# 4                            False            False
#
#    StreamingTV_No internet service  StreamingTV_Yes  \
# 0                            False            False
# 1                            False            False
# 2                            False            False
# 3                            False            False
# 4                            False            False
#
#    StreamingMovies_No internet service  StreamingMovies_Yes  \
# 0                                False                False
# 1                                False                False
# 2                                False                False
# 3                                False                False
# 4                                False                False
#
#    Contract_One year  Contract_Two year  PaperlessBilling_Yes  \
# 0              False              False                  True
# 1               True              False                 False
# 2              False              False                  True
# 3               True              False                 False
# 4              False              False                  True
#
#    PaymentMethod_Credit card (automatic)  PaymentMethod_Electronic check  \
# 0                                  False                            True
# 1                                  False                           False
# 2                                  False                           False
# 3                                  False                           False
# 4                                  False                            True
#
#    PaymentMethod_Mailed check  PreferredContactMethod_Phone  \
# 0                       False                         False
# 1                        True                          True
# 2                        True                         False
# 3                       False                         False
# 4                       False                         False
#
#    PreferredContactMethod_SMS
# 0                        True
# 1                       False
# 2                        True
# 3                       False
# 4                        True

# %%
# Identify numeric columns
numeric_columns = df.select_dtypes(include=['float64', 'int64']).columns

# Initialize list for columns needing scaling
columns_needs_to_be_scaled = []

# Check for values outside the [0,1] range
for column in numeric_columns:
    if (df[column].max() > 1) or (df[column].min() < 0):  # Check max and min values
        columns_needs_to_be_scaled.append(column)

# Display results
print("Columns with values greater than 1 or less than 0:")
print(columns_needs_to_be_scaled)
# Out:
# Columns with values greater than 1 or less than 0:
# ['tenure', 'MonthlyCharges', 'TotalCharges', 'AverageCallDuration', 'NumberOfComplaints']

# %%
from sklearn.preprocessing import MinMaxScaler

# Columns to scale
columns_to_scale = ['tenure', 'MonthlyCharges', 'TotalCharges', 'AverageCallDuration', 'NumberOfComplaints']

# Initialize MinMaxScaler
scaler = MinMaxScaler()

# Fit and transform on training data
X_train[columns_to_scale] = scaler.fit_transform(X_train[columns_to_scale])

# Transform test data using the same scaler
X_test[columns_to_scale] = scaler.transform(X_test[columns_to_scale])

# %%
X_train.head()
# Out:
#       SeniorCitizen    tenure  MonthlyCharges  TotalCharges  \
# 2374            0.0  0.388889        0.460228      0.165631
# 2973            0.0  0.777778        0.076731      0.174363
# 3329            0.0  0.361111        0.715994      0.280618
# 1479            0.0  0.305556        0.069756      0.067001
# 5387            0.0  0.097222        0.612357      0.069393
#
#       AverageCallDuration  NumberOfComplaints  gender_Male  Partner_Yes  \
# 2374             0.103544                 1.0        False         True
# 2973             0.878736                 0.4         True        False
# 3329             0.765538                 1.0        False         True
# 1479             0.265228                 0.6         True        False
# 5387             0.845748                 1.0        False        False
#
#       Dependents_Yes  PhoneService_Yes  MultipleLines_No phone service  \
# 2374            True              True                           False
# 2973           False              True                           False
# 3329           False              True                           False
# 1479           False              True                           False
# 5387           False              True                           False
#
#       MultipleLines_Yes  InternetService_Fiber optic  InternetService_No  \
# 2374               True                        False               False
# 2973               True                        False                True
# 3329               True                         True               False
# 1479               True                        False                True
# 5387              False                         True               False
#
#       InternetService_OutlierService  OnlineSecurity_No internet service  \
# 2374                            True                               False
# 2973                           False                                True
# 3329                           False                               False
# 1479                           False                                True
# 5387                           False                               False
#
#       OnlineSecurity_Yes  OnlineBackup_No internet service  OnlineBackup_Yes  \
# 2374               False                             False             False
# 2973               False                              True             False
# 3329                True                             False              True
# 1479               False                              True             False
# 5387               False                             False             False
#
#       DeviceProtection_No internet service  DeviceProtection_Yes  \
# 2374                                 False                 False
# 2973                                  True                 False
# 3329                                 False                  True
# 1479                                  True                 False
# 5387                                 False                 False
#
#       TechSupport_No internet service  TechSupport_Yes  \
# 2374                            False             True
# 2973                             True            False
# 3329                            False             True
# 1479                             True            False
# 5387                            False            False
#
#       StreamingTV_No internet service  StreamingTV_Yes  \
# 2374                            False            False
# 2973                             True            False
# 3329                            False             True
# 1479                             True            False
# 5387                            False             True
#
#       StreamingMovies_No internet service  StreamingMovies_Yes  \
# 2374                                False                 True
# 2973                                 True                False
# 3329                                False                 True
# 1479                                 True                False
# 5387                                False                False
#
#       Contract_One year  Contract_Two year  PaperlessBilling_Yes  \
# 2374               True              False                  True
# 2973              False               True                  True
# 3329               True              False                  True
# 1479              False               True                 False
# 5387              False              False                  True
#
#       PaymentMethod_Credit card (automatic)  PaymentMethod_Electronic check  \
# 2374                                  False                            True
# 2973                                  False                           False
# 3329                                   True                           False
# 1479                                  False                           False
# 5387                                  False                            True
#
#       PaymentMethod_Mailed check  PreferredContactMethod_Phone  \
# 2374                       False                         False
# 2973                       False                         False
# 3329                       False                         False
# 1479                        True                          True
# 5387                       False                         False
#
#       PreferredContactMethod_SMS
# 2374                        True
# 2973                        True
# 3329                        True
# 1479                       False
# 5387                       False

# %%
X_test.head()
# Out:
#       SeniorCitizen    tenure  MonthlyCharges  TotalCharges  \
# 4981       0.160826  0.388889        0.010463      0.020352
# 241        1.000000  0.208333        0.559542      0.129127
# 6414       0.000000  0.777778        0.460228      0.691317
# 6538       0.000000  0.069444        0.780269      0.058878
# 944        0.000000  0.777778        0.618336      0.549907
#
#       AverageCallDuration  NumberOfComplaints  gender_Male  Partner_Yes  \
# 4981             0.389387                 0.0         True        False
# 241              0.687293                 1.0         True        False
# 6414             0.991755                 1.0        False         True
# 6538             0.399266                 0.0         True        False
# 944              0.540003                 0.4        False         True
#
#       Dependents_Yes  PhoneService_Yes  MultipleLines_No phone service  \
# 4981           False              True                           False
# 241            False              True                           False
# 6414           False              True                           False
# 6538           False              True                           False
# 944            False              True                           False
#
#       MultipleLines_Yes  InternetService_Fiber optic  InternetService_No  \
# 4981              False                        False                True
# 241               False                         True               False
# 6414              False                         True               False
# 6538               True                         True               False
# 944               False                         True               False
#
#       InternetService_OutlierService  OnlineSecurity_No internet service  \
# 4981                           False                                True
# 241                            False                               False
# 6414                           False                               False
# 6538                           False                               False
# 944                            False                               False
#
#       OnlineSecurity_Yes  OnlineBackup_No internet service  OnlineBackup_Yes  \
# 4981               False                              True             False
# 241                False                             False              True
# 6414               False                             False             False
# 6538               False                             False              True
# 944                 True                             False             False
#
#       DeviceProtection_No internet service  DeviceProtection_Yes  \
# 4981                                  True                 False
# 241                                  False                 False
# 6414                                 False                 False
# 6538                                 False                  True
# 944                                  False                  True
#
#       TechSupport_No internet service  TechSupport_Yes  \
# 4981                             True            False
# 241                             False            False
# 6414                            False             True
# 6538                            False            False
# 944                             False            False
#
#       StreamingTV_No internet service  StreamingTV_Yes  \
# 4981                             True            False
# 241                             False            False
# 6414                            False             True
# 6538                            False            False
# 944                             False            False
#
#       StreamingMovies_No internet service  StreamingMovies_Yes  \
# 4981                                 True                False
# 241                                 False                False
# 6414                                False                 True
# 6538                                False                 True
# 944                                 False                False
#
#       Contract_One year  Contract_Two year  PaperlessBilling_Yes  \
# 4981               True              False                  True
# 241               False              False                  True
# 6414              False              False                  True
# 6538              False              False                 False
# 944               False               True                 False
#
#       PaymentMethod_Credit card (automatic)  PaymentMethod_Electronic check  \
# 4981                                  False                           False
# 241                                   False                            True
# 6414                                  False                            True
# 6538                                  False                            True
# 944                                   False                           False
#
#       PaymentMethod_Mailed check  PreferredContactMethod_Phone  \
# 4981                        True                         False
# 241                        False                          True
# 6414                       False                         False
# 6538                       False                         False
# 944                        False                         False
#
#       PreferredContactMethod_SMS
# 4981                       False
# 241                        False
# 6414                        True
# 6538                        True
# 944                         True

# %%
class_counts = df['Churn'].value_counts()
class_counts
# Out:
# Churn
# 0    4736
# 1    1707
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10, 6)) 
class_counts.plot(kind='bar')
plt.title('Class Distribution')
plt.xlabel('Class')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %%
from imblearn.over_sampling import SMOTE

# Define features (X) and target (y)
X = df.drop(columns=['Churn'])
y = df['Churn']

# Apply SMOTE
smote = SMOTE(sampling_strategy='auto', random_state=42)
X_resampled, y_resampled = smote.fit_resample(X, y)

# Verify new class distribution
import matplotlib.pyplot as plt
import pandas as pd

plt.figure(figsize=(10, 6)) 
pd.Series(y_resampled).value_counts().plot(kind='bar')
plt.title('Balanced Class Distribution (After SMOTE)')
plt.xlabel('Class')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %%
from sklearn.ensemble import RandomForestClassifier

rf_classifier = RandomForestClassifier(n_jobs=-1, random_state=42)

rf_classifier.fit(X_train, y_train)

importances = rf_classifier.feature_importances_

feature_importance_df = pd.DataFrame({'Feature': X_train.columns, 'Importance': importances})

feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False).reset_index(drop=True)

feature_importance_df
# Out:
#                                   Feature  Importance
# 0                                  tenure    0.137664
# 1                            TotalCharges    0.129331
# 2                          MonthlyCharges    0.116453
# 3                     AverageCallDuration    0.106570
# 4                      NumberOfComplaints    0.055201
# 5                       Contract_Two year    0.042444
# 6          PaymentMethod_Electronic check    0.031145
# 7             InternetService_Fiber optic    0.029256
# 8                    PaperlessBilling_Yes    0.021685
# 9                      OnlineSecurity_Yes    0.021142
# 10                            gender_Male    0.020935
# 11                        TechSupport_Yes    0.020692
# 12                      Contract_One year    0.020199
# 13                          SeniorCitizen    0.019679
# 14           PreferredContactMethod_Phone    0.018724
# 15             PreferredContactMethod_SMS    0.018345
# 16                            Partner_Yes    0.017781
# 17                       OnlineBackup_Yes    0.017633
# 18                      MultipleLines_Yes    0.017353
# 19                    StreamingMovies_Yes    0.015542
# 20                         Dependents_Yes    0.015213
# 21                   DeviceProtection_Yes    0.015111
# 22                        StreamingTV_Yes    0.014187
# 23             PaymentMethod_Mailed check    0.011479
# 24  PaymentMethod_Credit card (automatic)    0.011249
# 25    StreamingMovies_No internet service    0.008472
# 26   DeviceProtection_No internet service    0.007823
# 27     OnlineSecurity_No internet service    0.007461
# 28        StreamingTV_No internet service    0.005700
# 29         InternetService_OutlierService    0.005095
# 30         MultipleLines_No phone service    0.005022
# 31                       PhoneService_Yes    0.004616
# 32        TechSupport_No internet service    0.004462
# 33       OnlineBackup_No internet service    0.003759
# 34                     InternetService_No    0.002576

# %%
#check optimal number of features

sorted_indices = np.argsort(importances)[::-1]
cumulative_importance = np.cumsum(importances[sorted_indices])

plt.plot(range(1, len(importances) + 1), cumulative_importance, 'b-')
plt.xlabel('Number of Features')
plt.ylabel('Cumulative Importance')
plt.title('Cumulative Importance of Features')
plt.grid(True)
plt.show()

# %%
df['Churn'] = df["Churn"].apply(lambda x: 1 if x == 'Yes' else 0)
df.to_excel('New_cleaned_data.xlsx', index=False)
# Out:
#       SeniorCitizen  tenure  MonthlyCharges  TotalCharges  Churn  \
# 0               0.0     1.0       29.850000         29.85      0
# 1               0.0    34.0       56.950000       1889.50      0
# 2               0.0    28.0       64.433883        108.15      1
# 3               0.0    45.0       42.300000       1840.75      0
# 4               0.0     2.0       70.700000        151.65      1
# ...             ...     ...             ...           ...    ...
# 6868            0.0    72.0       21.150000       1419.40      0
# 6869            0.0    24.0       84.800000       1990.50      0
# 6870            0.0    72.0      103.200000       7362.90      0
# 6871            0.0    11.0       29.600000        346.45      0
# 6872            1.0     4.0       74.400000        306.60      1
#
#       AverageCallDuration  NumberOfComplaints  gender_Male  Partner_Yes  \
# 0               17.526822                 2.0        False         True
# 1               10.601054                 3.0         True        False
# 2               45.091316                 3.0         True        False
# 3               14.931076                 4.0         True        False
# 4                8.830655                 2.0        False        False
# ...                   ...                 ...          ...          ...
# 6868            45.351335                 2.0        False        False
# 6869            49.425165                 1.0         True         True
# 6870            24.468577                 0.0        False         True
# 6871            13.796117                 1.0        False         True
# 6872            40.658946                 1.0         True         True
#
#       Dependents_Yes  PhoneService_Yes  MultipleLines_No phone service  \
# 0              False             False                            True
# 1              False              True                           False
# 2              False              True                           False
# 3              False             False                            True
# 4              False              True                           False
# ...              ...               ...                             ...
# 6868           False              True                           False
# 6869            True              True                           False
# 6870            True              True                           False
# 6871            True             False                            True
# 6872           False              True                           False
#
#       MultipleLines_Yes  InternetService_Fiber optic  InternetService_No  \
# 0                 False                        False               False
# 1                 False                        False               False
# 2                 False                        False               False
# 3                 False                        False               False
# 4                 False                         True               False
# ...                 ...                          ...                 ...
# 6868              False                        False                True
# 6869               True                        False               False
# 6870               True                         True               False
# 6871              False                        False               False
# 6872               True                         True               False
#
#       InternetService_OutlierService  OnlineSecurity_No internet service  \
# 0                              False                               False
# 1                              False                               False
# 2                              False                               False
# 3                              False                               False
# 4                              False                               False
# ...                              ...                                 ...
# 6868                           False                                True
# 6869                           False                               False
# 6870                           False                               False
# 6871                           False                               False
# 6872                           False                               False
#
#       OnlineSecurity_Yes  OnlineBackup_No internet service  OnlineBackup_Yes  \
# 0                  False                             False              True
# 1                   True                             False             False
# 2                   True                             False              True
# 3                   True                             False             False
# 4                  False                             False             False
# ...                  ...                               ...               ...
# 6868               False                              True             False
# 6869                True                             False             False
# 6870               False                             False              True
# 6871                True                             False             False
# 6872               False                             False             False
#
#       DeviceProtection_No internet service  DeviceProtection_Yes  \
# 0                                    False                 False
# 1                                    False                  True
# 2                                    False                 False
# 3                                    False                  True
# 4                                    False                 False
# ...                                    ...                   ...
# 6868                                  True                 False
# 6869                                 False                  True
# 6870                                 False                  True
# 6871                                 False                 False
# 6872                                 False                 False
#
#       TechSupport_No internet service  TechSupport_Yes  \
# 0                               False            False
# 1                               False            False
# 2                               False            False
# 3                               False             True
# 4                               False            False
# ...                               ...              ...
# 6868                             True            False
# 6869                            False             True
# 6870                            False            False
# 6871                            False            False
# 6872                            False            False
#
#       StreamingTV_No internet service  StreamingTV_Yes  \
# 0                               False            False
# 1                               False            False
# 2                               False            False
# 3                               False            False
# 4                               False            False
# ...                               ...              ...
# 6868                             True            False
# 6869                            False             True
# 6870                            False             True
# 6871                            False            False
# 6872                            False            False
#
#       StreamingMovies_No internet service  StreamingMovies_Yes  \
# 0                                   False                False
# 1                                   False                False
# 2                                   False                False
# 3                                   False                False
# 4                                   False                False
# ...                                   ...                  ...
# 6868                                 True                False
# 6869                                False                 True
# 6870                                False                 True
# 6871                                False                False
# 6872                                False                False
#
#       Contract_One year  Contract_Two year  PaperlessBilling_Yes  \
# 0                 False              False                  True
# 1                  True              False                 False
# 2                 False              False                  True
# 3                  True              False                 False
# 4                 False              False                  True
# ...                 ...                ...                   ...
# 6868              False               True                  True
# 6869               True              False                  True
# 6870               True              False                  True
# 6871              False              False                  True
# 6872              False              False                  True
#
#       PaymentMethod_Credit card (automatic)  PaymentMethod_Electronic check  \
# 0                                     False                            True
# 1                                     False                           False
# 2                                     False                           False
# 3                                     False                           False
# 4                                     False                            True
# ...                                     ...                             ...
# 6868                                  False                           False
# 6869                                  False                           False
# 6870                                   True                           False
# 6871                                  False                            True
# 6872                                  False                           False
#
#       PaymentMethod_Mailed check  PreferredContactMethod_Phone  \
# 0                          False                         False
# 1                           True                          True
# 2                           True                         False
# 3                          False                         False
# 4                          False                         False
# ...                          ...                           ...
# 6868                       False                         False
# 6869                        True                         False
# 6870                       False                         False
# 6871                       False                          True
# 6872                        True                         False
#
#       PreferredContactMethod_SMS
# 0                           True
# 1                          False
# 2                           True
# 3                          False
# 4                           True
# ...                          ...
# 6868                        True
# 6869                       False
# 6870                       False
# 6871                       False
# 6872                        True
#
# [6443 rows x 36 columns]

# %%
import pandas as pd
import numpy as np
from statsmodels.stats.outliers_influence import variance_inflation_factor

X_train_clean = X_train.copy()

X_train_clean = pd.get_dummies(X_train_clean, drop_first=True)

X_train_clean = X_train_clean.astype(float)

# Replace infinite values with NaN, then drop NaNs
X_train_clean.replace([np.inf, -np.inf], np.nan, inplace=True)
X_train_clean.dropna(inplace=True)

# Compute VIF
vif = pd.DataFrame()
vif["Variable"] = X_train_clean.columns
vif["VIF"] = [variance_inflation_factor(X_train_clean.values, i) for i in range(X_train_clean.shape[1])]
vif = vif.sort_values(by='VIF', ascending=False)

print(vif)
# Out:
#                                  Variable        VIF
# 15     OnlineSecurity_No internet service  73.022837
# 17       OnlineBackup_No internet service  66.722144
# 23        StreamingTV_No internet service  66.036112
# 21        TechSupport_No internet service  55.140135
# 25    StreamingMovies_No internet service  51.799625
# 19   DeviceProtection_No internet service  50.017611
# 2                          MonthlyCharges  37.752264
# 9                        PhoneService_Yes  30.924172
# 1                                  tenure  12.739656
# 3                            TotalCharges  11.837109
# 13                     InternetService_No   7.694422
# 12            InternetService_Fiber optic   5.925490
# 4                     AverageCallDuration   3.981936
# 5                      NumberOfComplaints   3.282554
# 28                      Contract_Two year   3.136998
# 26                    StreamingMovies_Yes   3.047927
# 29                   PaperlessBilling_Yes   3.018429
# 24                        StreamingTV_Yes   3.006934
# 31         PaymentMethod_Electronic check   2.943841
# 10         MultipleLines_No phone service   2.833473
# 7                             Partner_Yes   2.750731
# 11                      MultipleLines_Yes   2.509486
# 20                   DeviceProtection_Yes   2.368643
# 32             PaymentMethod_Mailed check   2.367740
# 18                       OnlineBackup_Yes   2.173704
# 34             PreferredContactMethod_SMS   2.123555
# 22                        TechSupport_Yes   2.046817
# 6                             gender_Male   2.041497
# 33           PreferredContactMethod_Phone   2.030288
# 30  PaymentMethod_Credit card (automatic)   1.955804
# 16                     OnlineSecurity_Yes   1.949692
# 8                          Dependents_Yes   1.948775
# 27                      Contract_One year   1.934344
# 14         InternetService_OutlierService   1.432862
# 0                           SeniorCitizen   1.393229

# %%
import time

from sklearn.metrics import classification_report, accuracy_score, precision_score, recall_score, f1_score

from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import AdaBoostClassifier, GradientBoostingClassifier, RandomForestClassifier
from xgboost import XGBClassifier

# %%
algorithms = [
    LogisticRegression(n_jobs=-1, random_state=42),
    DecisionTreeClassifier(random_state=42),
    KNeighborsClassifier(n_jobs=-1),
    GaussianNB(),
    AdaBoostClassifier(random_state=42),
    GradientBoostingClassifier(random_state=42),
    RandomForestClassifier(n_jobs=-1, random_state=42),
    XGBClassifier(n_jobs=-1, random_state=42),
    SVC(random_state=42)
]

# Initialize the results dictionary for training data
results_train = {
    'Algorithm': [],
    'Accuracy': [],
    'Precision': [],
    'Recall': [],
    'F1-score': [],
    'Building Time (s)': []
}

# Apply the algorithms and calculate performance metrics for training data
for algorithm in algorithms:
    start_time = time.time()  # Start timer

    algorithm_name = type(algorithm).__name__
    algorithm.fit(X_train, y_train)
    y_train_pred = algorithm.predict(X_train)

    accuracy = accuracy_score(y_train, y_train_pred)
    precision = precision_score(y_train, y_train_pred, average='weighted')
    recall = recall_score(y_train, y_train_pred, average='weighted')
    f1 = f1_score(y_train, y_train_pred, average='weighted')

    end_time = time.time()  # End timer
    building_time = end_time - start_time

    results_train['Algorithm'].append(algorithm_name)
    results_train['Accuracy'].append(accuracy)
    results_train['Precision'].append(precision)
    results_train['Recall'].append(recall)
    results_train['F1-score'].append(f1)
    results_train['Building Time (s)'].append(building_time)

# Create a dataframe for the training data results
df_train = pd.DataFrame(results_train)
df_train
# Out:
#                     Algorithm  Accuracy  Precision    Recall  F1-score  \
# 0          LogisticRegression  0.791131   0.781007  0.791131  0.783646
# 1      DecisionTreeClassifier  1.000000   1.000000  1.000000  1.000000
# 2        KNeighborsClassifier  0.819290   0.814655  0.819290  0.816373
# 3                  GaussianNB  0.670288   0.794027  0.670288  0.688697
# 4          AdaBoostClassifier  0.793126   0.781364  0.793126  0.783065
# 5  GradientBoostingClassifier  0.824612   0.816747  0.824612  0.816500
# 6      RandomForestClassifier  1.000000   1.000000  1.000000  1.000000
# 7               XGBClassifier  0.980266   0.980212  0.980266  0.980221
# 8                         SVC  0.818847   0.810081  0.818847  0.808394
#
#    Building Time (s)
# 0           2.404481
# 1           0.050222
# 2           0.243256
# 3           0.009593
# 4           0.182543
# 5           0.639976
# 6           0.142055
# 7           0.150593
# 8           0.892928
